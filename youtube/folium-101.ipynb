# %% [markdown]
# # Folium 101
#
# Importing libraries

# %%
#Creatinginteractive.maps.ipynb

# %%
import pandas as pd
import folium

# %% [markdown]
# Our first map

# %%
world = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073])
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4ee51b1c126074acc448c721fecf4e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4ee51b1c126074acc448c721fecf4e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c4ee51b1c126074acc448c721fecf4e7 = L.map(
#                 &quot;map_c4ee51b1c126074acc448c721fecf4e7&quot;,
#                 {
#                     center: [13.133932434766733, 16.103938729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c96059eb33dfedcc540572db9fe973c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4ee51b1c126074acc448c721fecf4e7);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
world.save('maps_htmls/world_empty.html')

# %% [markdown]
# ## Marking places
#
# Reading data

# %%
cities = pd.read_csv('cities.csv')
print(cities.shape)
cities.head(3)
# Out:
# (22, 5)
#      name   latitude  longitude lived visited
# 0  Olinda  -7.998127 -34.908203   yes     yes
# 1  Recife  -8.052200 -34.928600   yes     yes
# 2   Miami  25.761700 -80.191800    no     yes

# %% [markdown]
# Marking some cities in the map

# %%
city = cities.iloc[0]
folium.Marker(
    location=[city['latitude'], city['longitude']],
).add_to(world)

world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4ee51b1c126074acc448c721fecf4e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4ee51b1c126074acc448c721fecf4e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c4ee51b1c126074acc448c721fecf4e7 = L.map(
#                 &quot;map_c4ee51b1c126074acc448c721fecf4e7&quot;,
#                 {
#                     center: [13.133932434766733, 16.103938729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c96059eb33dfedcc540572db9fe973c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4ee51b1c126074acc448c721fecf4e7);
#
#
#             var marker_8ed443a13e829ad24a1643a75d25ce3d = L.marker(
#                 [-7.9981267, -34.9082027],
#                 {}
#             ).addTo(map_c4ee51b1c126074acc448c721fecf4e7);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
world.save('maps_htmls/world_some_cities.html')

# %% [markdown]
# Let's add all cities I've been to to the map

# %%
world_all_cities = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
    ).add_to(world_all_cities)

world_all_cities
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_509a2fc438cb9fe3bdf8ea405ef896c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_509a2fc438cb9fe3bdf8ea405ef896c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_509a2fc438cb9fe3bdf8ea405ef896c2 = L.map(
#                 &quot;map_509a2fc438cb9fe3bdf8ea405ef896c2&quot;,
#                 {
#                     center: [13.133932434766733, 16.103938729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0b697d269f25fe4ef0be9c75727f2e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_9e96bf914fcd5e8f890c5cbf481d871f = L.marker(
#                 [-7.9981267, -34.9082027],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_39f6b09d6cfff3e8902d0badcc5a2d9d = L.marker(
#                 [-8.0522, -34.9286],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_b28c9005b021dd3901600bd5a2b6ec17 = L.marker(
#                 [25.7617, -80.1918],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_32c3eb8e4a230d02411336ca2d2ec0ed = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_2b32990d1a568f8f7e9914e9fa5b3407 = L.marker(
#                 [47.0707, 15.4395],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_12fe14e696787dc4c35ad2f50fae9b6e = L.marker(
#                 [25.033, 121.5654],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_6d5a7bf807641d22f95314f06861dc77 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_f2d1015cd476c44344f22396eab4cd13 = L.marker(
#                 [-23.5372, -46.7962],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_75d62a61f2a107ab3180369975fb2eb0 = L.marker(
#                 [-21.1704, -47.8103],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_cf91d3b80c6c2cd1f5db74925d9fcae6 = L.marker(
#                 [-27.5986, -48.5187],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_fad3a16d1b3acdbc109463606e3096c0 = L.marker(
#                 [-22.9099, -47.0626],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_bd0c3f758370ed0fd67c6ee34edafabf = L.marker(
#                 [-12.9777, -38.5016],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_a0b0790c4218243b7fd9dca6b6a32666 = L.marker(
#                 [-9.6498, -35.7089],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_ab03e43da3327151fa49a128b0420f51 = L.marker(
#                 [-19.9167, -43.9345],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_ba6c9d5355adc1cd5e98c0d50f26dd34 = L.marker(
#                 [-22.0087, -47.8909],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_884d1624aeb607f9b635b2491c97dfc3 = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_efe95dd43937440c3b5601f4e04a039c = L.marker(
#                 [43.6532, -79.3832],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_c01c76bf536af5f3855482bef56cd665 = L.marker(
#                 [53.3498, -6.2603],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_cd58d24d284890e86eb713652b2d23be = L.marker(
#                 [52.3676, 4.9041],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_a6e463b7f0251ad86dfca42a92ed43f5 = L.marker(
#                 [-33.8688, 151.2093],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_f1309b20554e17f2a677353acfd494a0 = L.marker(
#                 [28.5383, -81.3792],
#                 {}
#             ).addTo(map_509a2fc438cb9fe3bdf8ea405ef896c2);
#
#
#             var marker_32af921a3c051c4d42c760e345ad0f35 =

# %%
world_all_cities.save('maps_htmls/world_all_cities.html')

# %% [markdown]
# ## Adding information to markers
# Using `popup` and `tooltip`

# %%
world_all_cities_popup = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
        popup=city['name'],
    ).add_to(world_all_cities_popup)
    
world_all_cities_popup
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46e410b93242073c2306a0eac58780b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46e410b93242073c2306a0eac58780b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_46e410b93242073c2306a0eac58780b2 = L.map(
#                 &quot;map_46e410b93242073c2306a0eac58780b2&quot;,
#                 {
#                     center: [13.133932434766733, 16.103938729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_079375f0f3b6a619d425f3446ba83455 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46e410b93242073c2306a0eac58780b2);
#
#
#             var marker_4eaa13b5bb789127059d03fb9ce239fe = L.marker(
#                 [-7.9981267, -34.9082027],
#                 {}
#             ).addTo(map_46e410b93242073c2306a0eac58780b2);
#
#
#         var popup_3d7bf083383d867cbb1f3013c6cfcada = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0ac3f6dbd99dec3fd7a459ee315163eb = $(`&lt;div id=&quot;html_0ac3f6dbd99dec3fd7a459ee315163eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Olinda&lt;/div&gt;`)[0];
#             popup_3d7bf083383d867cbb1f3013c6cfcada.setContent(html_0ac3f6dbd99dec3fd7a459ee315163eb);
#
#
#         marker_4eaa13b5bb789127059d03fb9ce239fe.bindPopup(popup_3d7bf083383d867cbb1f3013c6cfcada)
#         ;
#
#
#
#
#             var marker_76b2db389ec2a886de413084ceb59eb4 = L.marker(
#                 [-8.0522, -34.9286],
#                 {}
#             ).addTo(map_46e410b93242073c2306a0eac58780b2);
#
#
#         var popup_78c5349ad6a940f1738a298ff9a0d868 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_04c64b8e97060ec3a69dd3633006d7ba = $(`&lt;div id=&quot;html_04c64b8e97060ec3a69dd3633006d7ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Recife&lt;/div&gt;`)[0];
#             popup_78c5349ad6a940f1738a298ff9a0d868.setContent(html_04c64b8e97060ec3a69dd3633006d7ba);
#
#
#         marker_76b2db389ec2a886de413084ceb59eb4.bindPopup(popup_78c5349ad6a940f1738a298ff9a0d868)
#         ;
#
#
#
#
#             var marker_47c9611d0986e567afed4e60ef5fdd6d = L.marker(
#                 [25.7617, -80.1918],
#                 {}
#             ).addTo(map_46e410b93242073c2306a0eac58780b2);
#
#
#         var popup_1b95fa1f8f757bb3b455d76a631f3b2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9a68d7fbdba26ab78b95db731b19a578 = $(`&lt;div id=&quot;html_9a68d7fbdba26ab78b95db731b19a578&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Miami&lt;/div&gt;`)[0];
#             popup_1b95fa1f8f757bb3b455d76a631f3b2d.setContent(html_9a68d7fbdba26ab78b95db731b19a578);
#
#
#         marker_47c9611d0986e567afed4e60ef5fdd6d.bindPopup(popup_1b95fa1f8f757bb3b455d76a631f3b2d)
#         ;
#
#
#
#
#             var marker_530be24f716fd5ee64069db4f4f82132 = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_46e410b93242073c2306a0eac58780b2);
#
#
#         var popup_9e8b75c09c35833fbe9dfbdd762a6371 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a7a4618b4c3097c27f0d6a64860ad517 = $(`&lt;div id=&quot;html_a7a4618b4c3097c27f0d6a64860ad517&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#             popup_9e8b75c09c35833fbe9dfbdd762a6371.setContent(html_a7a4618b4c3097c27f0d6a64860ad517);
#
#
#         marker_530be24f716fd5ee64069db4f4f82132.bindPopup(popup_9e8b75c09c35833fbe9dfbdd762a6371)
#         ;
#
#
#
#
#             var marker_41d56a33bde3796faff12b9f0e4a7f92 = L.marker(
#                 [47.0707, 15.4395],
#                 {}
#             ).addTo(map_46e410b93242073c2306a0eac58780b2);
#
#
#         var popup_5ded5bf81e63d948f6b8799117aede25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_46a4d9e28279b8495824c04ee045265e = $(`&lt;div id=&quot;html_46a4d9e28279b8495824c04ee045265e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Graz&lt;/div&gt;`)[0];
#             popup_5ded5bf81e63d948f6b8799117aede25.setContent(html_46a4d9e28279b8495824c04ee045265e);
#
#
#         marker_41d56a33bde3796faff12b9f0e4a7f92.bindPopup(popup_5ded5bf81e63d948f6b8799117aede25)
#         ;
#
#
#
#
#             var marker_4937a336b4d3cec87d000d8fee2e8dcc = L.marker(
#                 [25.033, 121.5654],
#                 {}
#             ).addTo(map_46e410b93242073c2306a0eac58780b2);
#
#
#         var popup_19ab855ebdd7de29060880eeea2ed4e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cfe6c97df8dc62f9ec2bd6b0cd4318d4 = $(`&lt;div id=&quot;html_cfe6c97df8dc62f9ec2bd6b0cd4318d4&quot; style=&quot;width: 100.0%; heigh

# %%
world_all_cities_popup.save('maps_htmls/world_all_cities_popup.html')

# %%
world_all_cities_tooltip = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
        popup=city['name'],
        tooltip=city['name'],
    ).add_to(world_all_cities_tooltip)
    
world_all_cities_tooltip
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcf09e8a29fb33fbd3d5b9e593bd8824 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcf09e8a29fb33fbd3d5b9e593bd8824&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fcf09e8a29fb33fbd3d5b9e593bd8824 = L.map(
#                 &quot;map_fcf09e8a29fb33fbd3d5b9e593bd8824&quot;,
#                 {
#                     center: [13.133932434766733, 16.103938729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d4c7c2b6331e47c6adbc2ededb29bcc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fcf09e8a29fb33fbd3d5b9e593bd8824);
#
#
#             var marker_1dd76d5198c7cb5307270240a5ae4270 = L.marker(
#                 [-7.9981267, -34.9082027],
#                 {}
#             ).addTo(map_fcf09e8a29fb33fbd3d5b9e593bd8824);
#
#
#         var popup_25befff678fa63f0f91f106d945497d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fa86861e8adb8b3356835549e890e828 = $(`&lt;div id=&quot;html_fa86861e8adb8b3356835549e890e828&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Olinda&lt;/div&gt;`)[0];
#             popup_25befff678fa63f0f91f106d945497d5.setContent(html_fa86861e8adb8b3356835549e890e828);
#
#
#         marker_1dd76d5198c7cb5307270240a5ae4270.bindPopup(popup_25befff678fa63f0f91f106d945497d5)
#         ;
#
#
#
#
#             marker_1dd76d5198c7cb5307270240a5ae4270.bindTooltip(
#                 `&lt;div&gt;
#                      Olinda
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0600a0dcd38270a240f1169da45a635a = L.marker(
#                 [-8.0522, -34.9286],
#                 {}
#             ).addTo(map_fcf09e8a29fb33fbd3d5b9e593bd8824);
#
#
#         var popup_b6e0ff2fa5f0fabba787dbdb2821dd8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8ef1fffdf5a9e93c1226e64c16436e98 = $(`&lt;div id=&quot;html_8ef1fffdf5a9e93c1226e64c16436e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Recife&lt;/div&gt;`)[0];
#             popup_b6e0ff2fa5f0fabba787dbdb2821dd8c.setContent(html_8ef1fffdf5a9e93c1226e64c16436e98);
#
#
#         marker_0600a0dcd38270a240f1169da45a635a.bindPopup(popup_b6e0ff2fa5f0fabba787dbdb2821dd8c)
#         ;
#
#
#
#
#             marker_0600a0dcd38270a240f1169da45a635a.bindTooltip(
#                 `&lt;div&gt;
#                      Recife
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cdcabf29785dc29b2c462eb37ca8ba71 = L.marker(
#                 [25.7617, -80.1918],
#                 {}
#             ).addTo(map_fcf09e8a29fb33fbd3d5b9e593bd8824);
#
#
#         var popup_51897923077a48780c669956c35c2ecc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e7252a16d6649a756a3917e1ae236e08 = $(`&lt;div id=&quot;html_e7252a16d6649a756a3917e1ae236e08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Miami&lt;/div&gt;`)[0];
#             popup_51897923077a48780c669956c35c2ecc.setContent(html_e7252a16d6649a756a3917e1ae236e08);
#
#
#         marker_cdcabf29785dc29b2c462eb37ca8ba71.bindPopup(popup_51897923077a48780c669956c35c2ecc)
#         ;
#
#
#
#
#             marker_cdcabf29785dc29b2c462eb37ca8ba71.bindTooltip(
#                 `&lt;div&gt;
#                      Miami
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6660cdd5da07f8140bf965bcee25bdc9 = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_fcf09e8a29fb33fbd3d5b9e593bd8824);
#
#
#         var popup_2870776117312391ac5236936e4541c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_08ba102ee6b93f1dff0434955be05591 = $(`&lt;div id=&quot;html_08ba102ee6b93f1dff0434955be05591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#             popup_2870776117312391ac5236936e4541c3.setContent(html_08ba102ee6b93f1dff0434955be05591);
#
#
#         marker_6660cdd5da07f8140bf965bcee25bdc9.bindPopup(popup_2870776117312391ac5236936e4541c3)
#         ;
#
#
#
#
#             marker_6660cdd5da07f8140bf965bcee25bdc9.bindTooltip(
#                 `&lt;div&gt;
#                      New York
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_47b81f66b7444cefd747ff7771e1d02d = L.marker(
#                 [47.0707, 15.4395],
#                 {}
#             ).addTo(map_fcf09e8a29fb33fbd3d5b9e593bd8824);
#
#
#         var popup_ed18808636484dbf29c390287849beca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %%
world_all_cities_tooltip.save('maps_htmls/world_all_cities_tooltip.html')

# %% [markdown]
# Looking closer into the dataset

# %%
cities.head(3)
# Out:
#      name   latitude  longitude lived visited
# 0  Olinda  -7.998127 -34.908203   yes     yes
# 1  Recife  -8.052200 -34.928600   yes     yes
# 2   Miami  25.761700 -80.191800    no     yes

# %%
cities.tail(3)
# Out:
#         name  latitude  longitude lived visited
# 19    Sydney  -33.8688   151.2093    no      no
# 20   Orlando   28.5383   -81.3792    no     yes
# 21  Brasília  -15.8267   -47.9218    no     yes

# %% [markdown]
# ## Coloring markers
#
# **Feature engineering**: creating a feature for coloring the markers

# %%
def select_marker_color(row):
    if row['lived'] == 'yes':
        return 'pink'
    elif row['lived'] == 'no' and row['visited'] == 'yes':
        return 'purple'
    return 'blue'

# %%
cities['colors'] = cities.apply(select_marker_color, axis=1)
cities.head(3)
# Out:
#      name   latitude  longitude lived visited  colors
# 0  Olinda  -7.998127 -34.908203   yes     yes    pink
# 1  Recife  -8.052200 -34.928600   yes     yes    pink
# 2   Miami  25.761700 -80.191800    no     yes  purple

# %% [markdown]
# Visualizing colored markers

# %%
world_all_cities_colored = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
        popup=city['name'],
        tooltip=city['name'],
        icon=folium.Icon(color=city['colors'], prefix='fa', icon='circle')
    ).add_to(world_all_cities_colored)
    
world_all_cities_colored
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bba8d7390822e10ac90d711389c96d0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bba8d7390822e10ac90d711389c96d0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_bba8d7390822e10ac90d711389c96d0e = L.map(
#                 &quot;map_bba8d7390822e10ac90d711389c96d0e&quot;,
#                 {
#                     center: [13.133932434766733, 16.103938729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b783cc1add93e601b76deabae57e455c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bba8d7390822e10ac90d711389c96d0e);
#
#
#             var marker_a36d16c521952bbb2df8ba7f4d4ea441 = L.marker(
#                 [-7.9981267, -34.9082027],
#                 {}
#             ).addTo(map_bba8d7390822e10ac90d711389c96d0e);
#
#
#             var icon_4469d9935acdcc38726e09658e6d5e0a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a36d16c521952bbb2df8ba7f4d4ea441.setIcon(icon_4469d9935acdcc38726e09658e6d5e0a);
#
#
#         var popup_75e3abbf75bab212d62c605e507135c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1c9cb06b65d649e5d4b2601711d01a74 = $(`&lt;div id=&quot;html_1c9cb06b65d649e5d4b2601711d01a74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Olinda&lt;/div&gt;`)[0];
#             popup_75e3abbf75bab212d62c605e507135c0.setContent(html_1c9cb06b65d649e5d4b2601711d01a74);
#
#
#         marker_a36d16c521952bbb2df8ba7f4d4ea441.bindPopup(popup_75e3abbf75bab212d62c605e507135c0)
#         ;
#
#
#
#
#             marker_a36d16c521952bbb2df8ba7f4d4ea441.bindTooltip(
#                 `&lt;div&gt;
#                      Olinda
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bf19c39547c9c0ccb1cc44874c2c4d78 = L.marker(
#                 [-8.0522, -34.9286],
#                 {}
#             ).addTo(map_bba8d7390822e10ac90d711389c96d0e);
#
#
#             var icon_12be12304822db6131f889890df615d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bf19c39547c9c0ccb1cc44874c2c4d78.setIcon(icon_12be12304822db6131f889890df615d5);
#
#
#         var popup_0c35d8fbeffa15f6b702727b79969993 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8664a65dd82affcd26940e96d8723a57 = $(`&lt;div id=&quot;html_8664a65dd82affcd26940e96d8723a57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Recife&lt;/div&gt;`)[0];
#             popup_0c35d8fbeffa15f6b702727b79969993.setContent(html_8664a65dd82affcd26940e96d8723a57);
#
#
#         marker_bf19c39547c9c0ccb1cc44874c2c4d78.bindPopup(popup_0c35d8fbeffa15f6b702727b79969993)
#         ;
#
#
#
#
#             marker_bf19c39547c9c0ccb1cc44874c2c4d78.bindTooltip(
#                 `&lt;div&gt;
#                      Recife
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_507e0878a8a2130ca9be3ba63902fee7 = L.marker(
#                 [25.7617, -80.1918],
#                 {}
#             ).addTo(map_bba8d7390822e10ac90d711389c96d0e);
#
#
#             var icon_5673738c21f848d6e8d0b956ea70469b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_507e0878a8a2130ca9be3ba63902fee7.setIcon(icon_5673738c21f848d6e8d0b956ea70469b);
#
#
#         var popup_f45c1a9085cabb038f64492e3c8a814f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0595733f42ac6b9f3bc1084de5f80474 = $(`&lt;div id=&quot;html_0595733f42ac6b9f3bc1084de5f80474&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Miami&lt;/div&gt;`)[0];
#             popup_f45c1a9085cabb038f64492e3c8a814f.setContent(html_0595733f42ac6b9f3bc1084de5f80474);
#
#
#         marker_507e0878a8a2130ca9be3ba63902fee7.bindPopup(popup_f45c1a9085cabb038f64492e3c8a814f)
#         ;
#
#
#
#
#             marker_507e0878a8a2130ca9be3ba63902fee7.bindTooltip(
#                 `&lt;div&gt;
#                      Miami
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}

# %%
world_all_cities_colored.save('maps_htmls/world_all_cities_colored.html')
